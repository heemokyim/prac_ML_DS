# %% [markdown]
# indexing 이랑 같은 기법?
#
# # Selection

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Data loading
# * xlrd 모듈이 없을경우 install 해야함

# %%
df= pd.read_excel("./data/excel-comp-data.xlsx")
df.head()
# Out:
#    account                         name                                street  \
# 0   211829   Kerluke, Koepp and Hilpert                    34456 Sean Highway
# 1   320563               Walter-Trantow                     1311 Alvis Tunnel
# 2   648336   Bashirian, Kunde and Price  62184 Schamberger Underpass Apt. 231
# 3   109996  D'Amore, Gleichner and Bode           155 Fadel Crescent Apt. 144
# 4   121213                Bauch-Goldner                   7274 Marissa Common
#
#               city          state  postal-code     Jan     Feb    Mar
# 0       New Jaycob          Texas        28752   10000   62000  35000
# 1    Port Khadijah  NorthCarolina        38365   95000   45000  35000
# 2   New Lilianland           Iowa        76517   91000  120000  35000
# 3       Hyattburgh          Maine        46021   45000  120000  10000
# 4  Shanahanchester     California        49681  162000  120000  35000

# %%
df["account"].head(3)
# Out:
# 0    211829
# 1    320563
# 2    648336
# Name: account, dtype: int64

# %%
df.head(3)
# Out:
#    account                        name                                street  \
# 0   211829  Kerluke, Koepp and Hilpert                    34456 Sean Highway
# 1   320563              Walter-Trantow                     1311 Alvis Tunnel
# 2   648336  Bashirian, Kunde and Price  62184 Schamberger Underpass Apt. 231
#
#              city          state  postal-code    Jan     Feb    Mar
# 0      New Jaycob          Texas        28752  10000   62000  35000
# 1   Port Khadijah  NorthCarolina        38365  95000   45000  35000
# 2  New Lilianland           Iowa        76517  91000  120000  35000

# %%
df[["account", "street", "state"]].head(-2)
# Out:
#     account                                street          state
# 0    211829                    34456 Sean Highway          Texas
# 1    320563                     1311 Alvis Tunnel  NorthCarolina
# 2    648336  62184 Schamberger Underpass Apt. 231           Iowa
# 3    109996           155 Fadel Crescent Apt. 144          Maine
# 4    121213                   7274 Marissa Common     California
# 5    132971                  89403 Casimer Spring       Arkansas
# 6    145068          340 Consuela Bridge Apt. 400     Mississipi
# 7    205217          91971 Cronin Vista Suite 601    RhodeIsland
# 8    209744                      26739 Grant Lock   Pennsylvania
# 9    212303             366 Maggio Grove Apt. 998          Idaho
# 10   214098             649 Cierra Forks Apt. 078       Tenessee
# 11   231907              18115 Olivine Throughway    NorthDakota
# 12   242368                       182 Bertie Road           Iowa

# %%
df[:5]
# Out:
#    account                         name                                street  \
# 0   211829   Kerluke, Koepp and Hilpert                    34456 Sean Highway
# 1   320563               Walter-Trantow                     1311 Alvis Tunnel
# 2   648336   Bashirian, Kunde and Price  62184 Schamberger Underpass Apt. 231
# 3   109996  D'Amore, Gleichner and Bode           155 Fadel Crescent Apt. 144
# 4   121213                Bauch-Goldner                   7274 Marissa Common
#
#               city          state  postal-code     Jan     Feb    Mar
# 0       New Jaycob          Texas        28752   10000   62000  35000
# 1    Port Khadijah  NorthCarolina        38365   95000   45000  35000
# 2   New Lilianland           Iowa        76517   91000  120000  35000
# 3       Hyattburgh          Maine        46021   45000  120000  10000
# 4  Shanahanchester     California        49681  162000  120000  35000

# %%
df["city"][4:7]
# Out:
# 4      Shanahanchester
# 5         Jeremieburgh
# 6    Lake Gabriellaton
# Name: city, dtype: object

# %%
account_sr = df["account"]
account_sr[:3]
# Out:
# 0    211829
# 1    320563
# 2    648336
# Name: account, dtype: int64

# %%
account_sr[[2, 7, 9]]
# Out:
# 2    648336
# 7    205217
# 9    212303
# Name: account, dtype: int64

# %%
account_sr[account_sr < 250000]
# Out:
# 0     211829
# 3     109996
# 4     121213
# 5     132971
# 6     145068
# 7     205217
# 8     209744
# 9     212303
# 10    214098
# 11    231907
# 12    242368
# Name: account, dtype: int64

# %%
df.index = df["account"]
df
# Out:
#          account                              name  \
# account
# 211829    211829        Kerluke, Koepp and Hilpert
# 320563    320563                    Walter-Trantow
# 648336    648336        Bashirian, Kunde and Price
# 109996    109996       D'Amore, Gleichner and Bode
# 121213    121213                     Bauch-Goldner
# 132971    132971  Williamson, Schumm and Hettinger
# 145068    145068                        Casper LLC
# 205217    205217                  Kovacek-Johnston
# 209744    209744                    Champlin-Morar
# 212303    212303                    Gerhold-Maggio
# 214098    214098       Goodwin, Homenick and Jerde
# 231907    231907                        Hahn-Moore
# 242368    242368      Frami, Anderson and Donnelly
# 268755    268755                       Walsh-Haley
# 273274    273274                     McDermott PLC
#
#                                        street               city  \
# account
# ...

# %%
del df['account']
df
# Out:
#                                      name  \
# account
# 211829         Kerluke, Koepp and Hilpert
# 320563                     Walter-Trantow
# 648336         Bashirian, Kunde and Price
# 109996        D'Amore, Gleichner and Bode
# 121213                      Bauch-Goldner
# 132971   Williamson, Schumm and Hettinger
# 145068                         Casper LLC
# 205217                   Kovacek-Johnston
# 209744                     Champlin-Morar
# 212303                     Gerhold-Maggio
# 214098        Goodwin, Homenick and Jerde
# 231907                         Hahn-Moore
# 242368       Frami, Anderson and Donnelly
# 268755                        Walsh-Haley
# 273274                      McDermott PLC
#
#                                        street               city  \
# account
# 211829                     34456 Sean Highway         New Jaycob
# 320563                      1311 Alvis Tunnel      Port Khadijah
# 648336   62184 Schamberger Underpass Apt. 231     New Lilianland
# ...

# %%
df[["name", "city"]][:5]
# Out:
#                                 name             city
# account
# 211829    Kerluke, Koepp and Hilpert       New Jaycob
# 320563                Walter-Trantow    Port Khadijah
# 648336    Bashirian, Kunde and Price   New Lilianland
# 109996   D'Amore, Gleichner and Bode       Hyattburgh
# 121213                 Bauch-Goldner  Shanahanchester

# %%
df.loc[[211829, 121213], ["name", "street"]]
# Out:
#                                name               street
# account
# 211829   Kerluke, Koepp and Hilpert   34456 Sean Highway
# 121213                Bauch-Goldner  7274 Marissa Common

# %%
df.iloc[:4, :3]
# Out:
#                                 name                                street  \
# account
# 211829    Kerluke, Koepp and Hilpert                    34456 Sean Highway
# 320563                Walter-Trantow                     1311 Alvis Tunnel
# 648336    Bashirian, Kunde and Price  62184 Schamberger Underpass Apt. 231
# 109996   D'Amore, Gleichner and Bode           155 Fadel Crescent Apt. 144
#
#                    city
# account
# 211829       New Jaycob
# 320563    Port Khadijah
# 648336   New Lilianland
# 109996       Hyattburgh

# %%
df.drop("street", axis=1)
# Out:
#                                      name               city          state  \
# account
# 211829         Kerluke, Koepp and Hilpert         New Jaycob          Texas
# 320563                     Walter-Trantow      Port Khadijah  NorthCarolina
# 648336         Bashirian, Kunde and Price     New Lilianland           Iowa
# 109996        D'Amore, Gleichner and Bode         Hyattburgh          Maine
# 121213                      Bauch-Goldner    Shanahanchester     California
# 132971   Williamson, Schumm and Hettinger       Jeremieburgh       Arkansas
# 145068                         Casper LLC  Lake Gabriellaton     Mississipi
# 205217                   Kovacek-Johnston         Deronville    RhodeIsland
# 209744                     Champlin-Morar    Lake Juliannton   Pennsylvania
# 212303                     Gerhold-Maggio          North Ras          Idaho
# 214098        Goodwin, Homenick and Jerde           Rosaberg       Tenessee
# ...

# %%
df # 실제로는 안 없어짐
# 판다스는 원본 데이터 삭제 안시킴
# 변환 시키고 싶으면 inplace 인자 써야함
# Out:
#                                      name  \
# account
# 211829         Kerluke, Koepp and Hilpert
# 320563                     Walter-Trantow
# 648336         Bashirian, Kunde and Price
# 109996        D'Amore, Gleichner and Bode
# 121213                      Bauch-Goldner
# 132971   Williamson, Schumm and Hettinger
# 145068                         Casper LLC
# 205217                   Kovacek-Johnston
# 209744                     Champlin-Morar
# 212303                     Gerhold-Maggio
# 214098        Goodwin, Homenick and Jerde
# 231907                         Hahn-Moore
# 242368       Frami, Anderson and Donnelly
# 268755                        Walsh-Haley
# 273274                      McDermott PLC
#
#                                        street               city  \
# account
# 211829                     34456 Sean Highway         New Jaycob
# 320563                      1311 Alvis Tunnel      Port Khadijah
# 648336   62184 Schamberger Underpass Apt. 231     New Lilianland
# ...

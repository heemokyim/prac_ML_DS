# %% [markdown]
# # matplotlib
#
# * pyplot 객체를 사용하여 데이터를 표시
# * pylot 객체에 그래프들을 쌓은 다음 show로 flush
# * 최대 단점 argument를 kwargs 받음
# * 그래서 matplotlib 사이트가서 찾아봐야됨

# %%
import matplotlib.pyplot as plt

X = [v / 10 for v in range(100)]
Y = [v ** 3 for v in X]
plt.plot(X, Y)
plt.show()

# %% [markdown]
# * graph는 figure 객체에 생성됨
# * pyplot 객체 사용시, 기본 firgure에 그래프가 그려짐

# %%
import numpy as np

x_1 = [v / 10 for v in range(100)]
y_1 = [np.cos(v) for v in x_1]

x_2 = [v / 10 for v in range(100)]
y_2 = [np.sin(v) for v in x_2]

line1, = plt.plot(x_1, y_1, label="cos")
line2, = plt.plot(x_2, y_2, label="sin")
plt.legend(handles=[line1, line2], loc="lower right") # legend
plt.title('test title') # title
plt.show()

# %%
X = [v / 10 for v in range(100)]
Y = [10 - v for v in X]

plt.plot(X, Y)
plt.plot(x_1, y_1)
plt.plot(y_2, x_2)
plt.show() # memory flush => draw

# %%
fig = plt.figure() # figure return
fig.set_size_inches(10, 5) # 크기 지정
ax_1_1 = fig.add_subplot(1, 2, 1) # (1,1) in (2,2)
ax_1_2 = fig.add_subplot(1, 2, 2) # (1,2) in (2,2)


ax_1_1.plot(x_1, y_1, c="b") # #eeefff 이런 식으로 컬러지정 가능
ax_1_2.plot(x_2, y_2, c="g")
plt.show()

fig = plt.figure() # figure return
fig.set_size_inches(10, 5) # 크기 지정
ax_2_1 = fig.add_subplot(1, 2, 1)
ax_2_2 = fig.add_subplot(1, 2, 2)

ax_2_1.plot(x_1, y_1, c="b", linestyle='dashed')
ax_2_1.plot(x_2, y_2, c="g", linestyle='dotted')
plt.title('clock')
ax_2_2.plot(x_1, y_1, c="b")
ax_2_2.plot(y_1, x_1, c="g")
ax_2_2.plot(Y, X, c='r')
plt.show()

# %% [markdown]
# # Scatter
#
# scatter 함수 사용, marker: scatter 모양 지정 가능

# %%
import numpy as np

# %%
data_1 = np.random.rand(512, 2)
data_2 = np.random.rand(512, 2)

data_1, data_2
# Out:
# (array([[0.81422335, 0.17621749],
#         [0.49016422, 0.90954467],
#         [0.06614902, 0.40926933],
#         ...,
#         [0.80260692, 0.16668011],
#         [0.2098677 , 0.23386502],
#         [0.47607267, 0.64236989]]), array([[0.35798653, 0.78486479],
#         [0.49377152, 0.21951272],
#         [0.79778808, 0.75175785],
#         ...,
#         [0.73521132, 0.2653443 ],
#         [0.41628049, 0.50320029],
#         [0.91582345, 0.56414693]]))

# %%
plt.scatter(data_1[:,0], data_1[:, 1], c='b', marker='x')
plt.scatter(data_2[:,0], data_2[:, 1], c='g', marker='^')

plt.show()

# %% [markdown]
# s : 크기 지정

# %%
N = 100
x = np.random.rand(N)
y = np.random.rand(N)
color = np.random.rand(N)
area = np.pi * (20 * np.random.rand(N)) ** 2 # pi * r ^ 2
plt.scatter(x, y, s=area, c=color, alpha=0.5)
plt.show()
color
# Out:
# array([0.20976653, 0.96860316, 0.28904503, 0.62229602, 0.41753257,
#        0.51316916, 0.37147624, 0.76084224, 0.00843604, 0.50681695,
#        0.29325647, 0.48586131, 0.71870473, 0.93941686, 0.6323205 ,
#        0.80907406, 0.06528485, 0.95206285, 0.84621824, 0.1432268 ,
#        0.53202416, 0.5167466 , 0.68238746, 0.17867356, 0.26110763,
#        0.94803569, 0.18274511, 0.7392561 , 0.93267156, 0.89470103,
#        0.67503878, 0.27638901, 0.85844695, 0.90013413, 0.66427124,
#        0.24207776, 0.91221417, 0.10804   , 0.4399214 , 0.9651797 ,
#        0.74442428, 0.34216806, 0.49857804, 0.55759811, 0.31261708,
#        0.68191974, 0.89810136, 0.73479704, 0.42716273, 0.7391546 ,
#        0.02292061, 0.84801852, 0.61313199, 0.30874912, 0.7208731 ,
#        0.38058136, 0.25533046, 0.19277427, 0.85740575, 0.94074156,
#        0.3920366 , 0.58765957, 0.15357251, 0.97030622, 0.73362737,
#        0.60712875, 0.14499089, 0.67386964, 0.10903074, 0.87926354,
#        0.60381462, 0.59294549, 0.62802856, 0.93791357, 0.58627512,
#        0.52867906, 0.77368673, 0.25513113, 0.78613472, 0.03145259,
#        0.89388338, 0.95617193, 0.74035793, 0.98622902, 0.39815366,
#        0.1968974 , 0.83900702, 0.87399069, 0.43675681, 0.04815783,
#        0.0917582 , 0.94003557, 0.15379308, 0.08366953, 0.1289619 ,
#        0.72144909, 0.9585926 , 0.55175515, 0.51664108, 0.60767495])

# %% [markdown]
# # histogram

# %%
X = np.random.randn(1000)
plt.hist(X, bins=50) # bins : 몇개의 바구니를 쓸것인가!
plt.show()
